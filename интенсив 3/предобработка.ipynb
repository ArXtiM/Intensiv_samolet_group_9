# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib

# %%
df = pd.read_csv(r'C:\\Users\\VikA\Desktop\\интенсив 3\\filtered_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 69 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Date                                                       260 non-null    object
#  1   Цена на арматуру                                           260 non-null    int64
#  2   Индекс стоимости грузоперевозок                            260 non-null    float64
#  3   Производство арматуры Сортовой прокат_Арматура             260 non-null    int64
#  4   Производство арматуры Сортовой прокат_Катанка              260 non-null    int64
#  5   Производство арматуры Сортовой прокат_Прутки прочие        260 non-null    int64
#  6   Производство сырья ЖРС_Агломерат                           260 non-null    int64
#  7   Производство сырья ЖРС_Аглоруда                            260 non-null    int64
# ...

# %%
cols = df.columns[:30] # первые 30 колонок
# определяем цвета 
# желтый - пропущенные данные, фиолетовый- не пропущенные
colours = ['#800080', '#ffff00'] 
sns.heatmap(df[cols].isnull(), cmap=sns.color_palette(colours))
# Out:
# <Axes: >

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Date - 0%
# Цена на арматуру - 0%
# Индекс стоимости грузоперевозок - 0%
# Производство арматуры Сортовой прокат_Арматура - 0%
# Производство арматуры Сортовой прокат_Катанка - 0%
# Производство арматуры Сортовой прокат_Прутки прочие - 0%
# Производство сырья ЖРС_Агломерат - 0%
# Производство сырья ЖРС_Аглоруда - 0%
# Производство сырья ЖРС_Концентрат - 0%
# Производство сырья ЖРС_Концентрат для дообогащения - 0%
# Производство сырья ЖРС_Окатыши - 0%
# Производство сырья Кокс_Кокс валовый - 0%
# Производство сырья Концентрат коксующегося угля_Жирные - 0%
# Производство сырья Концентрат коксующегося угля_Коксовые - 0%
# Производство сырья Концентрат коксующегося угля_Отощающие - 0%
# Производство сырья Металлизованная продукция_ГБЖ - 0%
# Производство сырья Металлизованная продукция_ПВЖ - 0%
# Производство сырья Рядовой коксующийся уголь_Газовые - 0%
# Производство сырья Рядовой коксующийся уголь_Жирные - 0%
# Производство сырья Рядовой коксующийся уголь_Коксовые - 0%
# ...

# %%
df.head()
# Out:
#          Date  Цена на арматуру  Индекс стоимости грузоперевозок  \
# 0  2017-09-11             39600                           1000.0
# 1  2017-09-18             38800                            991.0
# 2  2017-09-25             38800                            992.0
# 3  2017-10-02             37500                            979.0
# 4  2017-10-09             37000                            985.0
#
#    Производство арматуры Сортовой прокат_Арматура  \
# 0                                             667
# 1                                             667
# 2                                             667
# 3                                             704
# 4                                             704
#
#    Производство арматуры Сортовой прокат_Катанка  \
# 0                                            241
# 1                                            241
# 2                                            241
# 3                                            264
# ...

# %%
cols = df.columns[:30] # первые 30 колонок
# определяем цвета 
# желтый - пропущенные данные, фиолетовый - не пропущенные
colours = ['#800080', '#ffff00'] 
sns.heatmap(df[cols].isnull(), cmap=sns.color_palette(colours))
# Out:
# <Axes: >

# %%
df_unique_subset = df.drop_duplicates() #удаление дубликатов

print(df_unique_subset)
# Out:
#            Date  Цена на арматуру  Индекс стоимости грузоперевозок  \
# 0    2017-09-11             39600                           1000.0
# 1    2017-09-18             38800                            991.0
# 2    2017-09-25             38800                            992.0
# 3    2017-10-02             37500                            979.0
# 4    2017-10-09             37000                            985.0
# ..          ...               ...                              ...
# 255  2022-08-01             47500                           1200.0
# 256  2022-08-08             49000                           1198.0
# 257  2022-08-15             47500                           1211.0
# 258  2022-08-22             46500                           1230.0
# 259  2022-08-29             46000                           1255.0
#
#      Производство арматуры Сортовой прокат_Арматура  \
# 0                                               667
# 1                                               667
# ...

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Date - 0%
# Цена на арматуру - 0%
# Индекс стоимости грузоперевозок - 0%
# Производство арматуры Сортовой прокат_Арматура - 0%
# Производство арматуры Сортовой прокат_Катанка - 0%
# Производство арматуры Сортовой прокат_Прутки прочие - 0%
# Производство сырья ЖРС_Агломерат - 0%
# Производство сырья ЖРС_Аглоруда - 0%
# Производство сырья ЖРС_Концентрат - 0%
# Производство сырья ЖРС_Концентрат для дообогащения - 0%
# Производство сырья ЖРС_Окатыши - 0%
# Производство сырья Кокс_Кокс валовый - 0%
# Производство сырья Концентрат коксующегося угля_Жирные - 0%
# Производство сырья Концентрат коксующегося угля_Коксовые - 0%
# Производство сырья Концентрат коксующегося угля_Отощающие - 0%
# Производство сырья Металлизованная продукция_ГБЖ - 0%
# Производство сырья Металлизованная продукция_ПВЖ - 0%
# Производство сырья Рядовой коксующийся уголь_Газовые - 0%
# Производство сырья Рядовой коксующийся уголь_Жирные - 0%
# Производство сырья Рядовой коксующийся уголь_Коксовые - 0%
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 69 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Date                                                       260 non-null    object
#  1   Цена на арматуру                                           260 non-null    int64
#  2   Индекс стоимости грузоперевозок                            260 non-null    float64
#  3   Производство арматуры Сортовой прокат_Арматура             260 non-null    int64
#  4   Производство арматуры Сортовой прокат_Катанка              260 non-null    int64
#  5   Производство арматуры Сортовой прокат_Прутки прочие        260 non-null    int64
#  6   Производство сырья ЖРС_Агломерат                           260 non-null    int64
#  7   Производство сырья ЖРС_Аглоруда                            260 non-null    int64
# ...

# %%
import pandas as pd
import numpy as np

# Загрузка данных
data = pd.read_csv('filtered_data.csv')

# Функция для удаления выбросов по IQR
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# Пример удаления выбросов для столбца 'Цена на арматуру'
cleaned_data = remove_outliers(data, 'Цена на арматуру')

# Сохранение очищенных данных
cleaned_data.to_csv('cleaned_data.csv', index=False)

# %%
df.to_csv('готовые_данные')
